# %%
# Function to draw protractor-like annotations
def draw_protractor(ax):
    # Draw the circle
    circle = plt.Circle((0, 0), 1, color="gray", fill=False, linestyle="dotted")
    ax.add_artist(circle)
    
    # Annotate specific angles (0, 30, 45, 60, 90 degrees)
    for angle in [0, 15, 30, 45, 60, 90]:
        angle_rad = np.radians(angle)
        x = np.cos(angle_rad)
        y = np.sin(angle_rad)
        ax.plot([0, x], [0, y], color="gray", linestyle="dotted")
        ax.text(x * 1.1, y * 1.1, f"{angle}°", fontsize=10, color="black", ha="center", va="center")

# %% [markdown]
# ## 0-90 degree

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate ALPHA and alpha as described in the code
n_points = 100
ALPHA = np.random.rand(n_points) * np.pi / 2  # Random values for ALPHA in [0, π/2]
alpha = (1 - np.cos(ALPHA)) * np.pi / 2  # Corrected alpha values

# Convert ALPHA and alpha into Cartesian coordinates for a circle of radius 1
x_ALPHA = np.cos(ALPHA)
y_ALPHA = np.sin(ALPHA)

x_alpha = np.cos(alpha)
y_alpha = np.sin(alpha)

# Plot
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Plot for ALPHA
ax[0].scatter(x_ALPHA, y_ALPHA, s=1, color='blue')
draw_protractor(ax[0])
ax[0].set_title("Distribution of ALPHA (Uncorrected)")
ax[0].set_xlabel("X")
ax[0].set_ylabel("Y")
ax[0].set_xlim(-1.1, 1.1)
ax[0].set_ylim(-0.1, 1.1)
ax[0].set_aspect('equal')

# Plot for alpha
ax[1].scatter(x_alpha, y_alpha, s=1, color='green')
draw_protractor(ax[1])
ax[1].set_title("Distribution of alpha (Corrected)")
ax[1].set_xlabel("X")
ax[1].set_ylabel("Y")
ax[1].set_xlim(-1.1, 1.1)
ax[1].set_ylim(-0.1, 1.1)
ax[1].set_aspect('equal')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 0-60 degree

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate ALPHA and alpha as described in the code
n_points = 100
ALPHA = np.random.rand(n_points) * np.pi / 3  # Random values for ALPHA in [0, π/2]
alpha = (1 - np.cos(ALPHA)) * np.pi / 3  # Corrected alpha values

# Convert ALPHA and alpha into Cartesian coordinates for a circle of radius 1
x_ALPHA = np.cos(ALPHA)
y_ALPHA = np.sin(ALPHA)

x_alpha = np.cos(alpha)
y_alpha = np.sin(alpha)

# Plot
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Plot for ALPHA
ax[0].scatter(x_ALPHA, y_ALPHA, s=1, color='blue')
draw_protractor(ax[0])
ax[0].set_title("Distribution of ALPHA (Uncorrected)")
ax[0].set_xlabel("X")
ax[0].set_ylabel("Y")
ax[0].set_xlim(-1.1, 1.1)
ax[0].set_ylim(-0.1, 1.1)
ax[0].set_aspect('equal')

# Plot for alpha
ax[1].scatter(x_alpha, y_alpha, s=1, color='green')
draw_protractor(ax[1])
ax[1].set_title("Distribution of alpha (Corrected)")
ax[1].set_xlabel("X")
ax[1].set_ylabel("Y")
ax[1].set_xlim(-1.1, 1.1)
ax[1].set_ylim(-0.1, 1.1)
ax[1].set_aspect('equal')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 0-45 degree (the code in our study)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate ALPHA and alpha as described in the code
n_points = 100
ALPHA = np.random.rand(n_points) * np.pi / 4.5  # Random values for ALPHA in [0, π/2]
alpha = (1 - np.cos(ALPHA)) * np.pi / 4.5  # Corrected alpha values

# Convert ALPHA and alpha into Cartesian coordinates for a circle of radius 1
x_ALPHA = np.cos(ALPHA)
y_ALPHA = np.sin(ALPHA)

x_alpha = np.cos(alpha)
y_alpha = np.sin(alpha)

# Plot with protractor-like angle annotations
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Plot for ALPHA
ax[0].scatter(x_ALPHA, y_ALPHA, s=1, color="blue")
draw_protractor(ax[0])
ax[0].set_title("Distribution of ALPHA (Uncorrected)")
ax[0].set_xlabel("X")
ax[0].set_ylabel("Y")
ax[0].set_xlim(-1.2, 1.2)
ax[0].set_ylim(-0.2, 1.2)
ax[0].set_aspect("equal")

# Plot for alpha
ax[1].scatter(x_alpha, y_alpha, s=1, color="green")
draw_protractor(ax[1])
ax[1].set_title("Distribution of alpha (Corrected)")
ax[1].set_xlabel("X")
ax[1].set_ylabel("Y")
ax[1].set_xlim(-1.2, 1.2)
ax[1].set_ylim(-0.2, 1.2)
ax[1].set_aspect("equal")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 0-15 degree

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate ALPHA and alpha as described in the code
n_points = 100
ALPHA = np.random.rand(n_points) * np.pi / 12  # Random values for ALPHA in [0, π/2]
alpha = (1 - np.cos(ALPHA)) * np.pi / 12  # Corrected alpha values

# Convert ALPHA and alpha into Cartesian coordinates for a circle of radius 1
x_ALPHA = np.cos(ALPHA)
y_ALPHA = np.sin(ALPHA)

x_alpha = np.cos(alpha)
y_alpha = np.sin(alpha)

# Plot with protractor-like angle annotations
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Plot for ALPHA
ax[0].scatter(x_ALPHA, y_ALPHA, s=1, color="blue")
draw_protractor(ax[0])
ax[0].set_title("Distribution of ALPHA (Uncorrected)")
ax[0].set_xlabel("X")
ax[0].set_ylabel("Y")
ax[0].set_xlim(-1.2, 1.2)
ax[0].set_ylim(-0.2, 1.2)
ax[0].set_aspect("equal")

# Plot for alpha
ax[1].scatter(x_alpha, y_alpha, s=1, color="green")
draw_protractor(ax[1])
ax[1].set_title("Distribution of alpha (Corrected)")
ax[1].set_xlabel("X")
ax[1].set_ylabel("Y")
ax[1].set_xlim(-1.2, 1.2)
ax[1].set_ylim(-0.2, 1.2)
ax[1].set_aspect("equal")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## fixed version: 0~60 degree

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate ALPHA and alpha as described in the code
n_points = 100
ALPHA = np.random.rand(n_points) * np.pi / 3  # Random values for ALPHA in [0, π/2]

max_angle_rad = np.radians(60)  # 最大角度をラジアンに変換（45度）
U = np.random.rand(n_points)  # 一様分布の乱数
alpha = np.arccos(1 - U * (1 - np.cos(max_angle_rad)))  # 補正式
# alpha = (1 - np.cos(ALPHA)) * np.pi / 4.5  # Corrected alpha values

# Convert ALPHA and alpha into Cartesian coordinates for a circle of radius 1
x_ALPHA = np.cos(ALPHA)
y_ALPHA = np.sin(ALPHA)

x_alpha = np.cos(alpha)
y_alpha = np.sin(alpha)

# Plot with protractor-like angle annotations
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Plot for ALPHA
ax[0].scatter(x_ALPHA, y_ALPHA, s=1, color="blue")
draw_protractor(ax[0])
ax[0].set_title("Distribution of ALPHA (Uncorrected)")
ax[0].set_xlabel("X")
ax[0].set_ylabel("Y")
ax[0].set_xlim(-1.2, 1.2)
ax[0].set_ylim(-0.2, 1.2)
ax[0].set_aspect("equal")

# Plot for alpha
ax[1].scatter(x_alpha, y_alpha, s=1, color="green")
draw_protractor(ax[1])
ax[1].set_title("Distribution of alpha (Corrected)")
ax[1].set_xlabel("X")
ax[1].set_ylabel("Y")
ax[1].set_xlim(-1.2, 1.2)
ax[1].set_ylim(-0.2, 1.2)
ax[1].set_aspect("equal")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## fixed version: 0~45 degree

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate ALPHA and alpha as described in the code
n_points = 100
ALPHA = np.random.rand(n_points) * np.pi / 4.5  # Random values for ALPHA in [0, π/2]

max_angle_rad = np.radians(45)  # 最大角度をラジアンに変換（45度）
U = np.random.rand(n_points)  # 一様分布の乱数
alpha = np.arccos(1 - U * (1 - np.cos(max_angle_rad)))  # 補正式
# alpha = (1 - np.cos(ALPHA)) * np.pi / 4.5  # Corrected alpha values

# Convert ALPHA and alpha into Cartesian coordinates for a circle of radius 1
x_ALPHA = np.cos(ALPHA)
y_ALPHA = np.sin(ALPHA)

x_alpha = np.cos(alpha)
y_alpha = np.sin(alpha)

# Plot with protractor-like angle annotations
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Plot for ALPHA
ax[0].scatter(x_ALPHA, y_ALPHA, s=1, color="blue")
draw_protractor(ax[0])
ax[0].set_title("Distribution of ALPHA (Uncorrected)")
ax[0].set_xlabel("X")
ax[0].set_ylabel("Y")
ax[0].set_xlim(-1.2, 1.2)
ax[0].set_ylim(-0.2, 1.2)
ax[0].set_aspect("equal")

# Plot for alpha
ax[1].scatter(x_alpha, y_alpha, s=1, color="green")
draw_protractor(ax[1])
ax[1].set_title("Distribution of alpha (Corrected)")
ax[1].set_xlabel("X")
ax[1].set_ylabel("Y")
ax[1].set_xlim(-1.2, 1.2)
ax[1].set_ylim(-0.2, 1.2)
ax[1].set_aspect("equal")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## fixed version: 0~15 degree

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate ALPHA and alpha as described in the code
n_points = 100
ALPHA = np.random.rand(n_points) * np.pi / 12  # Random values for ALPHA in [0, π/2]

max_angle_rad = np.radians(15)  # 最大角度をラジアンに変換（15度）
U = np.random.rand(n_points)  # 一様分布の乱数
alpha = np.arccos(1 - U * (1 - np.cos(max_angle_rad)))  # 補正式
# alpha = (1 - np.cos(ALPHA)) * np.pi / 4.5  # Corrected alpha values

# Convert ALPHA and alpha into Cartesian coordinates for a circle of radius 1
x_ALPHA = np.cos(ALPHA)
y_ALPHA = np.sin(ALPHA)

x_alpha = np.cos(alpha)
y_alpha = np.sin(alpha)

# Plot with protractor-like angle annotations
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Plot for ALPHA
ax[0].scatter(x_ALPHA, y_ALPHA, s=1, color="blue")
draw_protractor(ax[0])
ax[0].set_title("Distribution of ALPHA (Uncorrected)")
ax[0].set_xlabel("X")
ax[0].set_ylabel("Y")
ax[0].set_xlim(-1.2, 1.2)
ax[0].set_ylim(-0.2, 1.2)
ax[0].set_aspect("equal")

# Plot for alpha
ax[1].scatter(x_alpha, y_alpha, s=1, color="green")
draw_protractor(ax[1])
ax[1].set_title("Distribution of alpha (Corrected)")
ax[1].set_xlabel("X")
ax[1].set_ylabel("Y")
ax[1].set_xlim(-1.2, 1.2)
ax[1].set_ylim(-0.2, 1.2)
ax[1].set_aspect("equal")

plt.tight_layout()
plt.show()

# %% [markdown]
# # MCMAC results analysis

# %% [markdown]
# ・'age' is absolute time
#
# ・'sep.kpc' is projected distance between two clusters
#
# ・'merger' shows the clusters is pre-merger or not
#
# ・'TSC_Catalog' shows Time Since Collision from Galaxy Cluster Merger Catalog.
#
#  We can calculate
#
#  TTC by "(1st apocentric passage's absolute time) - (TSC at 1st apocentric passage) - (dataframe's age) "
#
# and
#
# TSC "(dataframe's age) - { (1st apocentric passage's absolute time) - (TSC at 1st apocentric passage)}".
#
#  For simple dataframe, we replaced TTC to TSC by putting minus symbol
#
# ・'TSC0' shows Time Since Collision from MCMAC-pre-merger and MCMAC-post-merger

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import re

# %%
results_default = []
results_weaklensing = []

# %%
def extract_parameters(filename):
    # Define the pattern to extract the parameters from the filename
    pattern = r'zh_(\d+)to(\d+)_b([\d.]+)_z_MCMAC.txt'
    
    # Search for the pattern in the filename
    match = re.search(pattern, filename)
    
    if match:
        # Extract the parameters
        param1 = match.group(1)
        param2 = match.group(2)
        b_value = match.group(3)
        
        # Format the parameters as "1:1 (b=0)"
        formatted_params = f"{param1}:{param2} (b={b_value})"
        
        return formatted_params
    else:
        return None

def plotImage(filename_default, filename_weaklensing, zoom_x_range, zoom_y_range, plot1_x_range, plot1_y_range, plot2_x_range, plot2_y_range, plot3_x_range, plot3_y_range, absolute_merge_time):
    df_default = pd.read_csv(filename_default, sep='\t')
    df_selected_default = df_default[['age','sep.kpc','merger', 'delta.t', 'TSC0', 'TSC0.lower', 'TSC0.upper']]

    df_weaklensing = pd.read_csv(filename_weaklensing, sep='\t')
    df_selected_weaklensing = df_weaklensing[['age','sep.kpc','merger', 'delta.t', 'TSC0', 'TSC0.lower', 'TSC0.upper']]

    # When we replace Time Till Collision to Time Since Collision, we need to set minus.
    # We got Time Till Collision by using MCMAC-pre code.
    df_selected_default.loc[df_selected_default['merger'] == 'pre', ['TSC0', 'TSC0.lower', 'TSC0.upper']] *= -1
    df_selected_weaklensing.loc[df_selected_weaklensing['merger'] == 'pre', ['TSC0', 'TSC0.lower', 'TSC0.upper']] *= -1

    # 差の計算
    difference_list = df_selected_default['TSC0'] - df_selected_weaklensing['TSC0']
    
    # 相対誤差の計算
    # df_selected_default = df_selected_default.copy()
    # df_selected_default['Absolute Residual'] = df_selected_default['TSC0'] - df_selected_default['delta.t']
    # df_selected_default.loc[:, 'Absolute Residual'] = df_selected_default['TSC0'] - df_selected_default['delta.t']
    # df_selected_weaklensing = df_selected_weaklensing.copy()
    # df_selected_weaklensing['Absolute Residual'] = df_selected_weaklensing['TSC0'] - df_selected_weaklensing['delta.t']
    # df_selected_weaklensing.loc[:, 'Absolute Residual'] = df_selected_weaklensing['TSC0'] - df_selected_weaklensing['delta.t']


    # プロットスタイルの設定
    plt.style.use('ggplot')

    # 図とグリッドスペックの作成
    fig = plt.figure(figsize=(12, 18))
    gs = gridspec.GridSpec(4, 1, height_ratios=[1, 1, 1, 3])

    # delta.t の範囲でフィルタリング
    df_zoomed = df_selected_default[(df_selected_default['delta.t'] >= -0.3) & (df_selected_default['delta.t'] <= 0.3)]
    df_zoomed_weaklensing = df_selected_weaklensing[(df_selected_weaklensing['delta.t'] >= -0.3) & (df_selected_weaklensing['delta.t'] <= 0.3)]

    # 最上部プロット (拡大図)
    ax_zoom = fig.add_subplot(gs[0])
    line_zoom2 = ax_zoom.errorbar(df_zoomed['delta.t'], df_zoomed['TSC0'], yerr=[np.abs(df_zoomed['TSC0'] - df_zoomed['TSC0.lower']), np.abs(df_zoomed['TSC0.upper'] - df_zoomed['TSC0'])], fmt='o', ecolor='red', capsize=5, markersize=6, color='red', label='TSC from MCMAC')
    line_zoom3 = ax_zoom.errorbar(df_zoomed_weaklensing['delta.t'], df_zoomed_weaklensing['TSC0'], yerr=[np.abs(df_zoomed_weaklensing['TSC0'] - df_zoomed_weaklensing['TSC0.lower']), np.abs(df_zoomed_weaklensing['TSC0.upper'] - df_zoomed_weaklensing['TSC0'])], fmt='o', ecolor='green', capsize=5, markersize=6, color='green', label='TSC from MCMAC with weak lensing')

    # 縦の点線を追加
    ax_zoom.axvline(color='black', linestyle='--')
    ax_zoom.axhline(color='black', linestyle='--')


    ax_zoom.set_xlabel('delta.t (TSC from catalogue)')
    ax_zoom.set_ylabel('TSC from Catalog')
    ax_zoom.set_xlim(zoom_x_range[0], zoom_x_range[1])
    ax_zoom.set_ylim(zoom_y_range[0], zoom_y_range[1])

    # 二つ目のy軸としてTSC from MCMACを追加
    ax_zoom2 = ax_zoom.twinx()
    ax_zoom2.set_ylabel('TSC from MCMAC')
    ax_zoom2.set_ylim(zoom_y_range[0], zoom_y_range[1])

    lines_zoom = [line_zoom2, line_zoom3]
    labels_zoom = [l.get_label() for l in lines_zoom]
    ax_zoom.legend(lines_zoom, labels_zoom, loc='upper left')

    # 上部プロット
    ax1 = fig.add_subplot(gs[1])
    ax1.set_xlabel('Absolute age (Gyr)')
    ax1.set_ylabel('TSC from Catalog')
    ax1.set_xlim(plot1_x_range[0], plot1_x_range[1])
    ax1.set_ylim(plot1_y_range[0], plot1_y_range[1])
    ax1.axvline(x=absolute_merge_time, color='black', linestyle='--')
    ax1.axhline(color='black', linestyle='--')

    ax2 = ax1.twinx()
    line2 = ax2.errorbar(df_selected_default['age'], df_selected_default['TSC0'], yerr=[np.abs(df_selected_default['TSC0'] - df_selected_default['TSC0.lower']), np.abs(df_selected_default['TSC0.upper'] - df_selected_default['TSC0'])], fmt='o', ecolor='red', capsize=5, markersize=6, color='red', label='TSC from MCMAC')
    line3 = ax2.errorbar(df_selected_weaklensing['age'], df_selected_weaklensing['TSC0'], yerr=[np.abs(df_selected_weaklensing['TSC0'] - df_selected_weaklensing['TSC0.lower']), np.abs(df_selected_weaklensing['TSC0.upper'] - df_selected_weaklensing['TSC0'])], fmt='o', ecolor='green', capsize=5, markersize=6, color='green', label='TSC from MCMAC with weak lensing')

    ax2.set_ylabel('TSC from MCMAC')
    ax2.set_ylim(plot1_y_range[0], plot1_y_range[1])

    ax7 = ax1.twiny()
    ax7.set_xlim(ax1.get_xlim())
    ax7.set_xticks(df_selected_default['age'][::4])
    relative_time_labels = [f'{val:.2f}' for val in df_selected_default['delta.t'].reindex(df_selected_default.index, fill_value=0)][::4]
    ax7.set_xticklabels(relative_time_labels, rotation=0, ha='center')
    ax7.set_xlabel('delta.t (TSC from catalogue)')

    lines = [line2, line3]
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels, loc='upper left')

    # 中部プロット
    ax3 = fig.add_subplot(gs[2])
    line4 = ax3.plot(df_selected_default['age'], difference_list, 'y-', label='Difference', marker='o', markersize=5)
    # line5 = ax3.plot(df_selected_weaklensing['age'], df_selected_weaklensing['Absolute Residual'], '-', label='Weak lensing', marker='o', markersize=5, color='green')

    ax3.set_xlabel('Absolute age (Gyr)')
    ax3.set_ylabel('Difference (Gyr)')
    ax3.set_xlim(plot2_x_range[0], plot2_x_range[1])
    ax3.set_ylim(plot2_y_range[0], plot2_y_range[1])
    ax3.axhline(color='black', linestyle='--')
    ax3.axvline(x=absolute_merge_time, color='black', linestyle='--')


    ax6 = ax3.twiny()
    ax6.set_xlim(ax3.get_xlim())
    ax6.set_xticks(df_selected_default['age'][::4])
    relative_time_labels = [f'{val:.2f}' for val in df_selected_default['delta.t'].reindex(df_selected_default.index, fill_value=0)][::4]
    ax6.set_xticklabels(relative_time_labels, rotation=0, ha='center')
    ax6.set_xlabel('delta.t (TSC from catalogue)')

    # 縦の点線を第2x軸に追加
    ax6.axvline(x=0.00, color='black', linestyle='--')

    lines_mid = [line4[0]]
    labels_mid = [l.get_label() for l in lines_mid]
    ax3.legend(lines_mid, labels_mid, loc='upper left')

    # 下部プロット
    ax4 = fig.add_subplot(gs[3])
    ax4.plot(df_selected_default['age'], df_selected_default['sep.kpc'], 'b-', label='Halo Separation', marker='o', markersize=5)
    ax4.set_xlabel('Absolute age (Gyr)')
    ax4.set_ylabel('Halo Separation (kpc)')
    ax4.set_xlim(plot3_x_range[0], plot3_x_range[1])
    ax4.set_ylim(plot3_y_range[0], plot3_y_range[1])
    ax4.axvline(x=absolute_merge_time, color='black', linestyle='--')


    ax5 = ax4.twiny()
    ax5.set_xlim(ax4.get_xlim())
    ax5.set_xticks(df_selected_default['age'][::4])
    relative_time_labels = [f'{val:.2f}' for val in df_selected_default['delta.t'].reindex(df_selected_default.index, fill_value=0)][::4]
    ax5.set_xticklabels(relative_time_labels, rotation=0, ha='center')
    ax5.set_xlabel('delta.t (TSC from catalogue)')

    # 縦の点線を第2x軸に追加
    ax5.axvline(x=0.0, color='black', linestyle='--')

    # Calculate metrics
    mae_default = mean_absolute_error(df_selected_default['delta.t'], df_selected_default['TSC0'])
    rmse_default = np.sqrt(mean_squared_error(df_selected_default['delta.t'], df_selected_default['TSC0']))
    r2_default = r2_score(df_selected_default['delta.t'], df_selected_default['TSC0'])

    mae_weaklensing = mean_absolute_error(df_selected_weaklensing['delta.t'], df_selected_weaklensing['TSC0'])
    rmse_weaklensing = np.sqrt(mean_squared_error(df_selected_weaklensing['delta.t'], df_selected_weaklensing['TSC0']))
    r2_weaklensing = r2_score(df_selected_weaklensing['delta.t'], df_selected_weaklensing['TSC0'])

    plt.tight_layout()
    plt.show()

    filename_default = extract_parameters(filename_default)
    # Print metrics
    print(f"Metrics for default:")
    print(f"MAE: {mae_default}")
    print(f"RMSE: {rmse_default}")
    print(f"R²: {r2_default}")
    results_default.append({
        "filename": filename_default,
        "MAE": mae_default,
        "RMSE": rmse_default,
        "R²": r2_default
    })

    filename_weaklensing = extract_parameters(filename_weaklensing)
    print(f"\nMetrics for weak lensing bias:")
    print(f"MAE: {mae_weaklensing}")
    print(f"RMSE: {rmse_weaklensing}")
    print(f"R²: {r2_weaklensing}")
    results_weaklensing.append({
        "filename": filename_weaklensing,
        "MAE": mae_weaklensing,
        "RMSE": rmse_weaklensing,
        "R²": r2_weaklensing
    })

# %% [markdown]
# ## Mass ratio 1:1 b=0kpc

# %%
filename_default = '../output_default/zh_1to1_b0_z_MCMAC.txt'
filename_weaklensing = '../output_weaklensing_bias/zh_1to1_b0_z_MCMAC.txt'

zoom_x_range = [-0.1, 0.08]
zoom_y_range = [-0.8, 1]
plot1_x_range = [0, 2]
plot1_y_range = [-4, 2]
plot2_x_range = [0, 2]
plot2_y_range = [-0.5, 0.2]
plot3_x_range = [0, 2]
plot3_y_range = [0, 3300]
absolute_merge_time = 2 - 0.68

plotImage(filename_default, filename_weaklensing, zoom_x_range, zoom_y_range, plot1_x_range, plot1_y_range, plot2_x_range, plot2_y_range, plot3_x_range, plot3_y_range, absolute_merge_time)
# Out:
# Metrics for default:
# MAE: 0.42293088994658323
# RMSE: 0.5204646343321299
# R²: -0.3284506371536031
#
# Metrics for weak lensing bias:
# MAE: 0.3487120010434707
# RMSE: 0.4099184848227972
# R²: 0.17594162390526202

# %% [markdown]
# ## Mass ratio 1:1 b=500kpc

# %%
filename_default = '../output_default/zh_1to1_b0.5_z_MCMAC.txt'
filename_weaklensing = '../output_weaklensing_bias/zh_1to1_b0.5_z_MCMAC.txt'

zoom_x_range = [-0.04, 0.16]
zoom_y_range = [-0.5, 1.2]
plot1_x_range = [0, 2]
plot1_y_range = [-4, 2]
plot2_x_range = [0, 2]
plot2_y_range = [-0.4, 0.1]
plot3_x_range = [0, 2]
plot3_y_range = [0, 3200]
absolute_merge_time = 2 - 0.66

plotImage(filename_default, filename_weaklensing, zoom_x_range, zoom_y_range, plot1_x_range, plot1_y_range, plot2_x_range, plot2_y_range, plot3_x_range, plot3_y_range, absolute_merge_time)
# Out:
# Metrics for default:
# MAE: 0.4411051087001366
# RMSE: 0.524029343710459
# R²: -0.2948716704129408
#
# Metrics for weak lensing bias:
# MAE: 0.3653613458861014
# RMSE: 0.4152356178399616
# R²: 0.1869734754671083

# %% [markdown]
# ## Mass ratio 1:1 b=1000kpc

# %%
filename_default = '../output_default/zh_1to1_b1_z_MCMAC.txt'
filename_weaklensing = '../output_weaklensing_bias/zh_1to1_b1_z_MCMAC.txt'

zoom_x_range = [-0.2, 0.1]
zoom_y_range = [-1, 1]
plot1_x_range = [0, 2]
plot1_y_range = [-4, 2.3]
plot2_x_range = [0, 2]
plot2_y_range = [-0.4, 0.1]
plot3_x_range = [0, 2]
plot3_y_range = [0, 3300]
absolute_merge_time = 2 - 0.6

plotImage(filename_default, filename_weaklensing, zoom_x_range, zoom_y_range, plot1_x_range, plot1_y_range, plot2_x_range, plot2_y_range, plot3_x_range, plot3_y_range, absolute_merge_time)
# Out:
# Metrics for default:
# MAE: 0.45727297244428433
# RMSE: 0.5113598841814034
# R²: -0.5296759824855994
#
# Metrics for weak lensing bias:
# MAE: 0.38720223375502305
# RMSE: 0.4141498711877281
# R²: -0.003370201965624986

# %% [markdown]
# ## Mass ratio 1:3 b=0kpc

# %%
filename_default = '../output_default/zh_1to3_b0_z_MCMAC.txt'
filename_weaklensing = '../output_weaklensing_bias/zh_1to3_b0_z_MCMAC.txt'

zoom_x_range = [-0.1, 0.1]
zoom_y_range = [-0.75, 1]
plot1_x_range = [0, 2]
plot1_y_range = [-4, 2.3]
plot2_x_range = [0, 2]
plot2_y_range = [-0.25, 0.05]
plot3_x_range = [0, 2]
plot3_y_range = [0, 2700]
absolute_merge_time = 2 - 0.8

plotImage(filename_default, filename_weaklensing, zoom_x_range, zoom_y_range, plot1_x_range, plot1_y_range, plot2_x_range, plot2_y_range, plot3_x_range, plot3_y_range, absolute_merge_time)
# Out:
# Metrics for default:
# MAE: 0.39290390871489184
# RMSE: 0.49873491457827374
# R²: -0.30501844186462734
#
# Metrics for weak lensing bias:
# MAE: 0.3500031623253365
# RMSE: 0.43558077523099725
# R²: 0.004561323447866972

# %% [markdown]
# ## Mass ratio 1:3 b=500kpc

# %%
filename_default = '../output_default/zh_1to3_b0.5_z_MCMAC.txt'
filename_weaklensing = '../output_weaklensing_bias/zh_1to3_b0.5_z_MCMAC.txt'

zoom_x_range = [-0.1, 0.1]
zoom_y_range = [-0.77, 0.77]
plot1_x_range = [0, 2]
plot1_y_range = [-4, 2.3]
plot2_x_range = [0, 2]
plot2_y_range = [-0.25, 0.1]
plot3_x_range = [0, 2]
plot3_y_range = [0, 2700]
absolute_merge_time = 2 - 0.76

plotImage(filename_default, filename_weaklensing, zoom_x_range, zoom_y_range, plot1_x_range, plot1_y_range, plot2_x_range, plot2_y_range, plot3_x_range, plot3_y_range, absolute_merge_time)
# Out:
# Metrics for default:
# MAE: 0.42205459413640756
# RMSE: 0.49480655816954144
# R²: -0.27737397080536885
#
# Metrics for weak lensing bias:
# MAE: 0.3793903256657053
# RMSE: 0.43411706646855985
# R²: 0.01675694570061126

# %% [markdown]
# ## Mass ratio 1:3 b=1000kpc

# %%
filename_default = '../output_default/zh_1to3_b1_z_MCMAC.txt'
filename_weaklensing = '../output_weaklensing_bias/zh_1to3_b1_z_MCMAC.txt'

zoom_x_range = [-0.12, 0.08]
zoom_y_range = [-1, 1]
plot1_x_range = [0, 2.5]
plot1_y_range = [-4.3, 3]
plot2_x_range = [0, 2.5]
plot2_y_range = [-0.25, 0.1]
plot3_x_range = [0, 2.5]
plot3_y_range = [0, 2700]
absolute_merge_time = 2.5 - 1.18

plotImage(filename_default, filename_weaklensing, zoom_x_range, zoom_y_range, plot1_x_range, plot1_y_range, plot2_x_range, plot2_y_range, plot3_x_range, plot3_y_range, absolute_merge_time)
# Out:
# Metrics for default:
# MAE: 0.4521296190608853
# RMSE: 0.5031628024948428
# R²: 0.14768588307656894
#
# Metrics for weak lensing bias:
# MAE: 0.40787462213151215
# RMSE: 0.4444158958506163
# R²: 0.3350916364661327

# %% [markdown]
# ## Mass ratio 1:10 b=0kpc

# %%
filename_default = '../output_default/zh_1to10_b0_z_MCMAC.txt'
filename_weaklensing = '../output_weaklensing_bias/zh_1to10_b0_z_MCMAC.txt'

zoom_x_range = [-0.04, 0.16]
zoom_y_range = [-0.4, 1.2]
plot1_x_range = [0, 2]
plot1_y_range = [-4, 2.3]
plot2_x_range = [0, 2]
plot2_y_range = [-0.15, 0.05]
plot3_x_range = [0, 2]
plot3_y_range = [0, 2500]
absolute_merge_time = 2 - 0.96

plotImage(filename_default, filename_weaklensing, zoom_x_range, zoom_y_range, plot1_x_range, plot1_y_range, plot2_x_range, plot2_y_range, plot3_x_range, plot3_y_range, absolute_merge_time)
# Out:
# Metrics for default:
# MAE: 0.3516289592127592
# RMSE: 0.4583474478487835
# R²: -0.010195074903482926
#
# Metrics for weak lensing bias:
# MAE: 0.33164786633653376
# RMSE: 0.4278912342712957
# R²: 0.11959522119653654

# %% [markdown]
# ## Mass ratio 1:10 b=500kpc

# %%
filename_default = '../output_default/zh_1to10_b0.5_z_MCMAC.txt'
filename_weaklensing = '../output_weaklensing_bias/zh_1to10_b0.5_z_MCMAC.txt'

zoom_x_range = [-0.14, 0.06]
zoom_y_range = [-0.75, 0.75]
plot1_x_range = [0, 2]
plot1_y_range = [-3.7, 3.7]
plot2_x_range = [0, 2]
plot2_y_range = [-0.75, 0.25]
plot3_x_range = [0, 2]
plot3_y_range = [0, 2400]
absolute_merge_time = 2.4 - 1.26

plotImage(filename_default, filename_weaklensing, zoom_x_range, zoom_y_range, plot1_x_range, plot1_y_range, plot2_x_range, plot2_y_range, plot3_x_range, plot3_y_range, absolute_merge_time)
# Out:
# Metrics for default:
# MAE: 0.4102071793955344
# RMSE: 0.4811390751060429
# R²: -0.2015645144501419
#
# Metrics for weak lensing bias:
# MAE: 0.4098555027597252
# RMSE: 0.4601360216493092
# R²: -0.09895093379931708

# %% [markdown]
# ## Mass ratio 1:10 b=1000kpc

# %%
filename_default = '../output_default/zh_1to10_b1_z_MCMAC.txt'
filename_weaklensing = '../output_weaklensing_bias/zh_1to10_b1_z_MCMAC.txt'

zoom_x_range = [-0.14, 0.06]
zoom_y_range = [-1, 1]
plot1_x_range = [0, 3]
plot1_y_range = [-3.7, 5]
plot2_x_range = [0, 3]
plot2_y_range = [-0.15, 0.2]
plot3_x_range = [0, 3]
plot3_y_range = [0, 2400]
absolute_merge_time = 3 - 1.76

plotImage(filename_default, filename_weaklensing, zoom_x_range, zoom_y_range, plot1_x_range, plot1_y_range, plot2_x_range, plot2_y_range, plot3_x_range, plot3_y_range, absolute_merge_time)
# Out:
# Metrics for default:
# MAE: 0.48568375219791876
# RMSE: 0.5078422830260537
# R²: 0.4420739931862525
#
# Metrics for weak lensing bias:
# MAE: 0.4394758973175841
# RMSE: 0.46207067088970816
# R²: 0.5381130441255516

# %%
# Convert results lists to dataframes
results_df_default = pd.DataFrame(results_default)
results_df_weaklensing = pd.DataFrame(results_weaklensing)

# Print the dataframes
print("Results for default:")
display(results_df_default)
print("\nResults for weak lensing:")
display(results_df_weaklensing)

average_improvement = {
    "MAE": results_df_default["MAE"].mean() - results_df_weaklensing["MAE"].mean(),
    "RMSE": results_df_default["RMSE"].mean() - results_df_weaklensing["RMSE"].mean(),
    "R²": results_df_weaklensing["R²"].mean() - results_df_default["R²"].mean()
}

print("Average Improvement")
print(average_improvement)

# Plot the results
fig, ax = plt.subplots(2, 1, figsize=(12, 12))

# Plot MAE and RMSE in the same plot
ax[0].plot(results_df_default['filename'], results_df_default['MAE'], 'r-', marker='o', label='MAE default')
ax[0].plot(results_df_weaklensing['filename'], results_df_weaklensing['MAE'], 'g-', marker='o', label='MAE weak lensing bias')
ax[0].plot(results_df_default['filename'], results_df_default['RMSE'], 'r:', marker='o', label='RMSE default')
ax[0].plot(results_df_weaklensing['filename'], results_df_weaklensing['RMSE'], 'g:', marker='o', label='RMSE weak lensing bias')
ax[0].set_title('MAE and RMSE Comparison')
ax[0].set_xlabel('Filename')
ax[0].set_ylabel('Metrics')
ax[0].legend()
ax[0].grid(True)

# Plot R² separately
ax[1].plot(results_df_default['filename'], results_df_default['R²'], 'r-.', marker='o', label='R² default')
ax[1].plot(results_df_weaklensing['filename'], results_df_weaklensing['R²'], 'g-.', marker='o', label='R² weak lensing bias')
ax[1].set_title('R² Comparison')
ax[1].set_xlabel('Filename')
ax[1].set_ylabel('R²')
ax[1].legend()
ax[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# Results for default:
#        filename       MAE      RMSE        R²
# 0     1:1 (b=0)  0.422931  0.520465 -0.328451
# 1   1:1 (b=0.5)  0.441105  0.524029 -0.294872
# 2     1:1 (b=1)  0.457273  0.511360 -0.529676
# 3     1:3 (b=0)  0.392904  0.498735 -0.305018
# 4   1:3 (b=0.5)  0.422055  0.494807 -0.277374
# 5     1:3 (b=1)  0.452130  0.503163  0.147686
# 6    1:10 (b=0)  0.351629  0.458347 -0.010195
# 7  1:10 (b=0.5)  0.410207  0.481139 -0.201565
# 8    1:10 (b=1)  0.485684  0.507842  0.442074
# Results for weak lensing:
#        filename       MAE      RMSE        R²
# 0     1:1 (b=0)  0.348712  0.409918  0.175942
# 1   1:1 (b=0.5)  0.365361  0.415236  0.186973
# 2     1:1 (b=1)  0.387202  0.414150 -0.003370
# 3     1:3 (b=0)  0.350003  0.435581  0.004561
# 4   1:3 (b=0.5)  0.379390  0.434117  0.016757
# 5     1:3 (b=1)  0.407875  0.444416  0.335092
# 6    1:10 (b=0)  0.331648  0.427891  0.119595
# 7  1:10 (b=0.5)  0.409856  0.460136 -0.098951
# 8    1:10 (b=1)  0.439476  0.462071  0.538113
# Average Improvement
# {'MAE': 0.04626600295426769, 'RMSE': 0.06626347835961743, 'R²': 0.29245583892856336}
